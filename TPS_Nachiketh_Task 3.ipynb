# %%
u1_19 = int(input("No of students in ug 2nd year in 2019 is"))
u2_19 = int(input("No. of students in ug  3rd year in 2019 is "))
u3_19 = int(input("no of students in ug 4th year 1n 2019 is "))
p1_19 = int(input("no of students in pg 1st year in 2019 is "))
p2_19 = int(input("no of students in pg 2nd year in 2019 is "))
f_19 = int(input("Total no of faculty in the department in 2019 is "))
s_19 = u1_19+u2_19+u3_19+p1_19+p2_19
print("no of students in the department",s_19)
sfr_19 = s_19/f_19
print("the sutdent faculty ratio is",sfr_19)
# Out:
# No of students in ug 2nd year in 2019 is20
# No. of students in ug  3rd year in 2019 is 0
# no of students in ug 4th year 1n 2019 is 30
# no of students in pg 1st year in 2019 is 40
# no of students in pg 2nd year in 2019 is 50
# Total no of faculty in the department in 2019 is 20
# no of students in the department 140
# the sutdent faculty ratio is 7.0

# %%
u1_20 = int(input("no of students in ug 2nd year in 2020 is "))
u2_20 = int(input("no of students in ug 3rd year in 2020 is "))
u3_20 = int(input("no of students in ug 4th year in 2020 is "))
p1_20 = int(input("no of students in pg 1st year in 2020 is "))
p2_20 = int(input("no of students in pg 2nd year in 2020 is "))
f_20 = int(input("total no of the faculty in the department  in 2020 is "))
s_20 = u1_20+u2_20+u3_20+p1_20+p2_20
print("no of students in the departtment",s_20)
sfr_20 = s_20/f_20
print("the student faclty ratio is ",sfr_20)
# Out:
# no of students in ug 2nd year in 2020 is 10
# no of students in ug 3rd year in 2020 is 30
# no of students in ug 4th year in 2020 is 40
# no of students in pg 1st year in 2020 is 50
# no of students in pg 2nd year in 2020 is 30
# total no of the faculty in the department  in 2020 is 3
# no of students in the departtment 160
# the student faclty ratio is  53.333333333333336

# %%
u1_21 = int(input("no of students in ug 2nd year in 2021 is "))
u2_21 = int(input("no of students in ug 3rd year in 2021 is "))
u3_21 = int(input("no of student in  ug  4th year in 2021 is "))
p1_21 = int(input("no of  student in pg 1st year in 2021 is "))
p2_21 = int(input("no of the student in pg 2nd year in 2021 is "))
f_21 = int(input("total no of the faculty in the dearment in 2021 is "))
s_21 = u1_21+u2_21+u3_21+p1_21+p2_21
print("no of student in the department ",s_21)
sfr_21 = s_21/f_21
print("the student faclty ratio is ",sfr_21)
# Out:
# no of students in ug 2nd year in 2021 is 10
# no of students in ug 3rd year in 2021 is 20
# no of student in  ug  4th year in 2021 is 30
# no of  student in pg 1st year in 2021 is 40
# no of the student in pg 2nd year in 2021 is 50
# total no of the faculty in the dearment in 2021 is 50
# no of student in the department  150
# the student faclty ratio is  3.0

# %%
avgsfr = sfr_19+sfr_20+sfr_21/3
print("the average sfr is ",avgsfr)
if (avgsfr<=15):
  print("20 marks")
elif (avgsfr<=17):
  print("18 marks")
elif (avgsfr<=19):
  print("16 marks")
elif (avgsfr<=21):
  print("14 marks")
elif (avgsfr<=23):
  print("12 marks")
elif (avgsfr<=25):
  print("10 marks")
elif (avgsfr > 25):
  print("0 marks")
# Out:
# the average sfr is  61.333333333333336
# 0 marks
